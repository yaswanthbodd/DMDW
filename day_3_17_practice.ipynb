# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ds=pd.read_csv('linear_regression.csv')
ds.head()
# Out:
#    X         Y
# 0  1  3.888889
# 1  2  4.555556
# 2  3  5.222222
# 3  4  5.888889
# 4  5  6.555556

# %%
ds.isnull().sum()
# Out:
# X    0
# Y    0
# dtype: int64

# %%
x=ds.iloc[:,:1]
x
# Out:
#        X
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
# ..   ...
# 295  296
# 296  297
# 297  298
# 298  299
# 299  300
#
# [300 rows x 1 columns]

# %%
y=ds.iloc[:,-1]
y
# Out:
# 0        3.888889
# 1        4.555556
# 2        5.222222
# 3        5.888889
# 4        6.555556
#           ...
# 295    200.555556
# 296    201.222222
# 297    201.888889
# 298      1.888889
# 299      1.888889
# Name: Y, Length: 300, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
x_train
# Out:
#        X
# 134  135
# 145  146
# 63    64
# 293  294
# 285  286
# ..   ...
# 251  252
# 192  193
# 117  118
# 47    48
# 172  173
#
# [240 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit_transform(x_train)
# Out:
# array([[-0.18292444],
#        [-0.05620691],
#        [-1.00082851],
#        [ 1.6487199 ],
#        [ 1.55656169],
#        [ 0.85385538],
#        [ 1.1764091 ],
#        [-0.44787928],
#        [-1.49617887],
#        [-1.1966647 ],
#        [ 0.07051063],
#        [ 0.89993448],
#        [ 1.41832439],
#        [-1.41554044],
#        [-0.06772668],
#        [ 1.25704753],
#        [-1.30034268],
#        [-0.60915614],
#        [ 0.47370278],
#        [-0.17140466],
#        [-0.36724085],
#        [ 0.11658973],
#        [ 1.3146464 ],
#        [ 0.73865762],
#        [ 1.01513224],
#        [-0.85107143],
#        [ 0.71561807],
#        [ 0.86537515],
#        [ 1.21096842],
#        [ 1.00361246],
#        [ 1.52200237],
#        [-1.21970425],
#        [ 1.40680461],
#        [ 0.45066323],
#        [ 0.02443152],
#        [ 0.09355018],
#        [-0.56307704],
#        [-1.1045065 ],
#        [ 0.35850502],
#        [-1.51921842],
#        [ 1.51048259],
#        [ 1.15336954],
#        [-0.27508264],
#        [ 0.24330726],
#        [-0.90867031],
#        [ 0.8884147 ],
#        [ 1.09577067],
#        [ 0.63497964],
#        [ 1.59112102],
#        [ 0.75017739],
#        [ 0.04747108],
#        [ 0.10506995],
#        [-1.34642179],
#        [-0.770433  ],
#        [ 1.14184977],
#        [-1.03538784],
#        [ 0.19722816],
#        [ 1.49896282],
#        [-0.45939906],
#        [-1.48465909],
#        [-1.39250089],
#        [-0.04468713],
#        [-1.54225797],
#        [-1.08146694],
#        [-0.86259121],
#        [-0.47091883],
#        [ 0.28938637],
#        [ 0.58890053],
#        [ 0.12810951],
#        [-1.68049528],
#        [-0.62067592],
#        [ 0.18570838],
#        [-1.02386807],
#        [-0.95474941],
#        [-0.14836511],
#        [ 0.55434121],
#        [ 1.29160685],
#        [ 1.48744304],
#        [-1.26578336],
#        [ 1.36072551],
#        [-1.5768173 ],
#        [-0.49395838],
#        [ 0.80777627],
#        [-1.69201506],
#        [ 0.0820304 ],
#        [-0.28660242],
#        [-1.45009977],
#        [-1.38098111],
#        [-0.83955165],
#        [ 1.62568035],
#        [ 0.69257852],
#        [-1.50769865],
#        [ 1.19944865],
#        [ 1.04969156],
#        [ 1.33768596],
#        [-0.80499233],
#        [-1.13906582],
#        [-1.70353483],
#        [ 0.98057291],
#        [-0.52851771],
#        [ 0.33546547],
#        [-0.73587367],
#        [-1.61137663],
#        [ 0.56586098],
#        [-1.05842739],
#        [-1.25426358],
#        [-1.56529752],
#        [ 0.05899085],
#        [-1.1505856 ],
#        [ 1.63720012],
#        [ 0.95753336],
#        [-0.30964197],
#        [ 0.57738076],
#        [-1.01234829],
#        [ 0.42762367],
#        [ 0.87689493],
#        [-0.22900354],
#        [ 0.68105874],
#        [ 1.2685673 ],
#        [-1.23122403],
#        [-0.41331995],
#        [-0.13684534],
#        [ 1.66023968],
#        [ 0.78473672],
#        [-0.0101278 ],
#        [-0.4363595 ],
#        [ 1.11881022],
#        [-0.59763636],
#        [ 0.77321695],
#        [-0.65523524],
#        [ 0.76169717],
#        [ 0.13962928],
#        [-1.31186246],
#        [ 0.32394569],
#        [-0.42483973],
#        [-1.72657438],
#        [-0.64371547],
#        [ 1.44136394],
#        [-0.63219569],
#        [ 1.68327923],
#        [ 1.28008708],
#        [ 1.03817179],
#        [-0.93170986],
#        [-1.16210537],
#        [-1.17362515],
#        [-0.74739345],
#        [ 1.694799  ],
#        [-0.10228601],
#        [ 0.65801919],
#        [-1.46161954],
#        [ 1.10729044],
#        [-0.02164758],
#        [-0.07924646],
#        [-0.82803188],
#        [ 0.34698524],
#        [-0.57459681],
#        [ 0.62345986],
#        [-0.21748377],
#        [ 1.34920573],
#        [ 1.70631878],
#        [ 0.53130166],
#        [-1.65745573],
#        [-0.94322964],
#        [ 0.61194009],
#        [-0.75891322],
#        [ 0.23178749],
#        [-0.33268152],
#        [-0.11380578],
#        [ 1.2224882 ],
#        [ 1.42984416],
#        [-0.09076623],
#        [ 1.23400797],
#        [-0.67827479],
#        [-0.78195278],
#        [ 1.53352214],
#        [-1.59985685],
#        [-0.35572107],
#        [-0.55155726],
#        [-1.32338223],
#        [-1.06994717],
#        [ 0.22026771],
#        [ 0.93449381],
#        [-0.97778896],
#        [-1.71505461],
#        [-0.3442013 ],
#        [ 1.37224528],
#        [ 0.4161039 ],
#        [-1.2427438 ],
#        [-0.51699793],
#        [-0.20596399],
#        [-0.8165121 ],
#        [-1.5307382 ],
#        [ 1.30312663],
#        [ 0.94601358],
#        [-1.28882291],
#        [-0.19444421],
#        [-1.11602627],
#        [ 1.24552775],
#        [-0.25204309],
#        [-1.40402066],
#        [ 0.38154457],
#        [ 0.15114906],
#        [ 0.01291175],
#        [ 1.08425089],
#        [ 0.60042031],
#        [-1.36946134],
#        [-1.35794156],
#        [-0.26356287],
#        [ 0.40458412],
#        [ 1.47592326],
#        [ 1.39528483],
#        [-0.03316735],
#        [ 1.45288371],
#        [ 0.31242592],
#        [-0.58611659],
#        [ 0.54282143],
#        [ 1.07273111],
#        [-0.40180018],
#        [ 1.32616618],
#        [-0.89715053],
#        [-1.43857999],
#        [ 0.17418861],
#        [ 1.57960125],
#        [ 0.27786659],
#        [ 1.6026408 ],
#        [-1.27730313],
#        [ 0.49674233],
#        [-0.71283412],
#        [-0.92019008],
#        [-0.7243539 ],
#        [ 1.06121134],
#        [ 1.46440349],
#        [ 0.70409829],
#        [-1.6228964 ],
#        [ 0.51978188],
#        [ 1.16488932],
#        [ 0.48522255],
#        [-0.37876063],
#        [-1.18514493],
#        [ 0.25482704]])

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Out:
# array([140.7642319 , 127.75959742,  13.31881395, 149.21724432,
#        160.92141535,  93.94754776, 155.06932984, 139.46376845,
#         39.32808292,  75.74105948, 194.08323329,  15.26950912,
#        125.15867052, 166.77350087,  19.82113119,  53.63318085,
#        181.0785988 ,  64.03688844, 154.41909811, 112.15403604,
#        129.06006087,  72.48990086,  86.14476707,  89.39592569,
#        149.86747604,  80.94291327, 131.66098776, 191.48230639,
#        157.67025673, 197.33439191,  65.33735189,  48.43132706,
#         10.71788705,  84.84430362, 147.91678087, 103.0507919 ,
#        119.95681673, 123.85820707, 199.93531881,   8.76719188,
#        150.51770777,  63.38665672,  58.18480292,  27.62391188,
#         41.27877809,  95.89824293, 158.97072018,  47.13086361,
#         10.06765533,  34.77646085,  52.98294913, 144.01539052,
#        118.00612155,  74.44059603,  43.87970499, 170.02465949,
#        114.75496293,  22.42205809, 190.18184294, 105.00148707])

# %%
plt.scatter(x_train,y_train,color='green')
plt.plot(x_train,lr.predict(x_train),color='blue')
plt.show()

# %%
plt.scatter(x_test,y_test,color='green')
plt.plot(x_test,lr.predict(x_test),color='blue')
plt.show()
